# %% [markdown]
# <a href="https://colab.research.google.com/github/Mouni560/455-crt-training-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv")

# %%
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df.head(7)
# Out:
#       video_id trending_date  \
# 0  m8Dqg8iz5Fo      18.09.05
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
# 5  qDAxDcjgn-8      17.18.11
# 6  kton-qrKNLc      18.08.03
#
#                                                title  \
# 0  MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
# 5             Taylor Swift - Reputation ALBUM REVIEW
# 6                        Meghan Trainor - No Excuses
#
#                              channel_title  category_id  \
# 0                              Sylvia Gani           26
# 1  Watch What Happens Live with Andy Cohen           24
# 2                              Food Wishes           26
# 3                                     TIME           25
# ...

# %%
df.tail(9)
# Out:
#          video_id trending_date  \
# 4991  ZqOtqz8bSDk      18.11.03
# 4992  _pP_C7HEy3g      18.16.05
# 4993  Sl-NvOZ23m8      17.08.12
# 4994  mkpINSUnDpA      17.13.12
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title       channel_title  \
# 4991     10 Things Jimmy Butler Can't Live Without | GQ                  GQ
# 4992                     The Coin Hexagon - Numberphile         Numberphile
# 4993                             i was so uncomfortable        ConnorFranta
# 4994  Ramsay Shuts Down Restaurant After Finding RAW...  Kitchen Nightmares
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice              SMTOWN
# 4996                   God of War – Story Trailer | PS4         PlayStation
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don          HalseyVEVO
# ...

# %%
#FROM 2 TO 8 ROW WANT TO FETCH THE DATA USE ILOC
#df.iloc[start :stop: step]
df.iloc[1:9:1]
# Out:
#       video_id trending_date  \
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
# 5  qDAxDcjgn-8      17.18.11
# 6  kton-qrKNLc      18.08.03
# 7  oRArmtMA9AI      18.15.03
# 8  84p7f-Rh-RY      17.21.12
#
#                                                title  \
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
# 5             Taylor Swift - Reputation ALBUM REVIEW
# 6                        Meghan Trainor - No Excuses
# 7            Marshmello - FLY (Official Music Video)
# 8  Kate Winslet On Working With Woody Allen | Los...
#
#                              channel_title  category_id  \
# 1  Watch What Happens Live with Andy Cohen           24
# 2                              Food Wishes           26
# ...

# %%
df.iloc[5:9:5]
# Out:
#       video_id trending_date                                   title  \
# 5  qDAxDcjgn-8      17.18.11  Taylor Swift - Reputation ALBUM REVIEW
#
#    channel_title  category_id              publish_time  \
# 5  theneedledrop           10  2017-11-14T23:06:27.000Z
#
#                                                 tags   views  likes  dislikes  \
# 5  album|"review"|"music"|"reviews"|"indie"|"unde...  274155  10765       750
#
#    comment_count                                  thumbnail_link  \
# 5           2560  https://i.ytimg.com/vi/qDAxDcjgn-8/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 5              False             False                   False
#
#                                          description  Genre
# 5  Listen: https://www.youtube.com/watch?v=3tmd-C...  Music

# %%
df.loc[3050:2636:1]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, Genre]
# Index: []

# %%
#we will get data in true or false if we write only code inside the bracet df['channel_title']=="TIME"
df['channel_title']=="TIME"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: channel_title, Length: 5000, dtype: bool

# %%
df[df['channel_title']=="TIME"]
# Out:
#          video_id trending_date  \
# 3     oTObwUiXdYY      17.19.11
# 156   ESKmRiLjNpg      18.19.05
# 302   NuZJQ-YS7_w      18.24.02
# 1385  BR7AnZ3S8u8      17.17.12
# 1590  0XARMt12oFk      17.28.12
# 2866  zsbT6NMUrSk      18.30.01
# 3225  cgYHbIEZWW8      18.22.02
# 4121  ESKmRiLjNpg      18.15.05
#
#                                                   title channel_title  \
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...          TIME
# 156   An Expert's Take On The Symbolism In Childish ...          TIME
# 302   Former Trump Adviser Rick Gates Is About To Pl...          TIME
# 1385  A Federal Judge In Philadelphia Blocks Preside...          TIME
# 1590  Multiple Casualties And Injuries Reported As A...          TIME
# 2866  Judge Aquilina Delivers Powerful Statement Bef...          TIME
# 3225  FBI Admits It Failed To Investigate Tip About ...          TIME
# 4121  An Expert's Take On The Symbolism In Childish ...          TIME
#
# ...

# %%
#to retrive data in which views are greater than or equal to 500000
df[df['views']>=500000]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 4     yvicqMrAHvQ      18.05.02
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 9     Biex1XR_mpo      18.24.03
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# 6                           Meghan Trainor - No Excuses
# 7               Marshmello - FLY (Official Music Video)
# 9                50 Mums | 50 Kids | 1 Extra Chromosome
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
df[df['comment_count']>=5000]#channel data which is having more than 5000 comments
# Out:
#          video_id trending_date  \
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 10    RQm0nKoODo4      18.13.03
# 17    QBL8IRJ5yHU      18.04.06
# 18    wW4JB9tjlik      18.10.06
# ...           ...           ...
# 4977  uVcvhKTVZ8g      18.04.05
# 4980  tfREC-AkX20      18.14.04
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title      channel_title  \
# 6                           Meghan Trainor - No Excuses  MeghanTrainorVEVO
# 7               Marshmello - FLY (Official Music Video)         Marshmello
# 10             Take On Me in 20 Styles ft. Seth Everman   Ten Second Songs
# 17    Why I'm So Scared (being myself and crying too...      grav3yardgirl
# 18    24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 UNDER...          Papa Jake
# ...                                                 ...                ...
# ...

# %%
#find out data of channel time whose comment freater than 50000
(df['channel_title']=="TIME") & (df['comment_count']>=5000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df[(df['channel_title']=="TIME") & (df['comment_count']>=500)]
# Out:
#          video_id trending_date  \
# 156   ESKmRiLjNpg      18.19.05
# 1590  0XARMt12oFk      17.28.12
# 2866  zsbT6NMUrSk      18.30.01
# 3225  cgYHbIEZWW8      18.22.02
# 4121  ESKmRiLjNpg      18.15.05
#
#                                                   title channel_title  \
# 156   An Expert's Take On The Symbolism In Childish ...          TIME
# 1590  Multiple Casualties And Injuries Reported As A...          TIME
# 2866  Judge Aquilina Delivers Powerful Statement Bef...          TIME
# 3225  FBI Admits It Failed To Investigate Tip About ...          TIME
# 4121  An Expert's Take On The Symbolism In Childish ...          TIME
#
#       category_id              publish_time  \
# 156            25  2018-05-08T17:52:37.000Z
# 1590           25  2017-12-18T18:26:52.000Z
# 2866           25  2018-01-24T20:24:08.000Z
# 3225           25  2018-02-16T18:45:03.000Z
# 4121           25  2018-05-08T17:52:37.000Z
#
# ...
